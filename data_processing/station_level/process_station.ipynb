# %%
import os
import pandas as pd 
import numpy as np
import datetime as d
import calendar as c 
from datetime import timedelta

# 数据保证起始站点为NYC站点，可视化系统的数据域为NYC站点
# new header ride_id | rideable_type | started_at | ended_at | start_station_name | start_station_id | end_station_name | end_station_id | start_lat | start_lng | end_lat| end_lng | member_casual
# old header tripduration | starttime | stoptime | start station id | start station name | start station latitude | start station longitude | end station id | end station name | end station latitude | end station longitude | bikeid | usertype | birth year | gender
raw_dirs = ['.\\old_raw\\', '.\\new_raw\\']
require_lists = [[['start station name', 'end station name'], ['start station name', 'start station latitude','start station longitude']],
                 [['start_station_name', 'end_station_name'], ['start_station_name', 'start_lat','start_lng']]]
station_NYC = []

for i in range(2):
    files = os.listdir(raw_dirs[i])
    path_list = [(raw_dirs[i] + f) for f in files if f.endswith('.csv')]

    for p in path_list:
        data = pd.read_csv(p, low_memory=False, index=False)
        data = data[data[require_lists[i][0]].notnull().all(1)]
        station_info = data[require_lists[i][1]].drop_duplicates()
        if i == 0:
            station_info.rename(columns={'start station name' : 'start_station_name', 'start station latitude' : 'start_lat', 'start station longitude' : 'start_lng'}, inplace=True) 
        station_NYC.append(station_info)

station_NYC = pd.concat(station_NYC, ignore_index=True)

# %%
station_NYC.drop_duplicates(inplace=True)
station_NYC
# Out:
#                     start_station_name  start_lat  start_lng
# 0          Central Park West & W 76 St  40.778968 -73.973747
# 1                Pershing Square North  40.751873 -73.977706
# 2              Amsterdam Ave & W 82 St  40.785247 -73.976673
# 3                      1 Ave & E 16 St  40.732219 -73.981656
# 4                       Great Jones St  40.727434 -73.993790
# ...                                ...        ...        ...
# 37875                  W 15 St & 7 Ave  40.780578 -73.985624
# 37878             Crescent St & 30 Ave  40.770374 -73.928607
# 37879             Broad St & Bridge St  40.717548 -74.013221
# 37886              FDR Drive & E 35 St  40.751581 -73.977910
# 37887  W 168th S & Fort Washington Ave  40.842102 -73.942240
#
# [3259 rows x 3 columns]

# %%
to_list = station_NYC.loc[station_NYC.duplicated(subset=['start_lat','start_lng'],keep=False)].sort_values(['start_lat','start_lng'])
to_list
# Out:
#                                   start_station_name  start_lat  start_lng
# 26894                                  5 Ave & 67 St  40.635679 -74.020005
# 26903                                  5 Ave & 66 St  40.635679 -74.020005
# 386    39 St & 2 Ave - Citi Bike HQ at Industry City  40.655400 -74.010628
# 10556                                  39 St & 2 Ave  40.655400 -74.010628
# 701    2 Ave & 36 St - Citi Bike HQ at Industry City  40.657089 -74.008702
# ...                                              ...        ...        ...
# 20766                     E 170 St & Webster Ave_old  40.836103 -73.907199
# 18577                               3 Ave & E 174 St  40.842240 -73.898500
# 23163   3 Ave & E 174 St - Bathgate Vaccination Site  40.842240 -73.898500
# 30753                     Grand Concourse & E 192 St  40.864480 -73.895220
# 33477                      Jerome Ave & W Fordham Rd  40.864480 -73.895220
#
# [158 rows x 3 columns]

# %%
to_list = to_list.groupby(['start_lat','start_lng'])
to_list

# %%
raw_dirs = ['.\\old_raw\\', '.\\new_raw\\']
data_lists = [[['start station name', 'end station name'], ['starttime', 'stoptime', 'start station name', 'start station latitude','start station longitude', 'end station name', 'end station latitude','end station longitude']],
                 [['start_station_name', 'end_station_name'], ['started_at', 'ended_at', 'start_station_name', 'start_lat','start_lng', 'end_station_name', 'end_lat','end_lng']]]
station_data = []

for i in range(2):
    files = os.listdir(raw_dirs[i])
    path_list = [(raw_dirs[i] + f) for f in files if f.endswith('.csv')]

    for p in path_list:
        data = pd.read_csv(p, low_memory=False, usecols=data_lists[i][1])
        data = data[data[data_lists[i][0]].notnull().all(1)]
        if i == 0:
            data.rename(columns={'start station name' : 'start_station_name', 'start station latitude' : 'start_lat', 'start station longitude' : 'start_lng',
                                 'end station name' : 'end_station_name', 'end station latitude' : 'end_lat', 'end station longitude' : 'end_lng', 'starttime' : 'started_at', 'stoptime' : 'ended_at'},inplace=True) 
        station_data.append(data)

station_data = pd.concat(station_data, ignore_index=True)
station_data
# Out:
#                         started_at                  ended_at  \
# 0         2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1         2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2         2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3         2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4         2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...                            ...                       ...
# 57409784       2021-08-31 17:52:14       2021-08-31 18:11:03
# 57409785       2021-08-16 18:42:15       2021-08-16 18:59:23
# 57409786       2021-08-09 16:58:49       2021-08-09 17:13:51
# 57409787       2021-08-15 12:24:58       2021-08-15 12:39:29
# 57409788       2021-08-08 17:15:03       2021-08-08 17:24:15
#
#                            start_station_name  start_lat  start_lng  \
# 0                 Central Park West & W 76 St  40.778968 -73.973747
# 1                       Pershing Square North  40.751873 -73.977706
# 2                     Amsterdam Ave & W 82 St  40.785247 -73.976673
# 3                             1 Ave & E 16 St  40.732219 -73.981656
# 4                              Great Jones St  40.727434 -73.993790
# ...                                       ...        ...        ...
# 57409784        Flushing Ave & Vanderbilt Ave  40.697950 -73.970776
# 57409785  W 147 St & Adam Clayton Powell Blvd  40.822810 -73.937413
# 57409786          W 82 St & Central Park West  40.782750 -73.971370
# 57409787              Grand St & Elizabeth St  40.718822 -73.995960
# 57409788             Bedford Ave & Nassau Ave  40.723117 -73.952123
#
#                     end_station_name    end_lat    end_lng
# 0             W 89 St & Columbus Ave  40.788221 -73.970416
# 1                    E 39 St & 2 Ave  40.747804 -73.973442
# 2                    E 77 St & 3 Ave  40.773142 -73.958562
# 3                    W 15 St & 6 Ave  40.738046 -73.996430
# 4                 E 20 St & Park Ave  40.738274 -73.987520
# ...                              ...        ...        ...
# 57409784                6 Ave & 9 St  40.668127 -73.983776
# 57409785    W 116 St & Amsterdam Ave  40.806758 -73.960708
# 57409786    W 110 St & Amsterdam Ave  40.802692 -73.962950
# 57409787  Greenwich Ave & Charles St  40.735238 -74.000271
# 57409788       Devoe St & Morgan Ave  40.713811 -73.935150
#
# [57409789 rows x 8 columns]

# %%
drop_index = []
correct_name = []
name = []
lat = []
lng = []
d_lat = []
d_lng = []
for i, v in to_list:
    loc_data = station_data.loc[(station_data['start_lat'] == i[0]) & (station_data['start_lng'] == i[1])]
    loc_num = loc_data.shape[0]
    correct_name.clear()
    same_loc = True

    for j in range(v.shape[0]):
        item = v.iloc[j,0]

        item_data = station_data.loc[(station_data['start_station_name'] == item)]
        item_lat = item_data.iloc[0,3]
        item_lng = item_data.iloc[0,4]
        
        if item_lat != i[0] or item_lng != i[1]:
            same_loc = False
        else:
            correct_name.append(item)


    if same_loc:
        print('rename', i, correct_name[0])
        drop_index.extend(v.index[1:])
        name.append(correct_name[0])
        lat.append(i[0])
        lng.append(i[1])
    elif len(correct_name):
        print('register wrong name', i, correct_name[0])
        drop_index.extend(v.index)
        name.append(correct_name[0])
        lat.append(i[0])
        lng.append(i[1])
    else:
        print('error data', i, loc_num)
        drop_index.extend(v.index)
        d_lat.append(i[0])
        d_lng.append(i[1])
# Out:
# rename (40.635679, -74.020005) 5 Ave & 67 St
# rename (40.65539977447831, -74.01062786579132) 39 St & 2 Ave - Citi Bike HQ at Industry City
# rename (40.65708866668485, -74.00870203971863) 2 Ave & 36 St - Citi Bike HQ at Industry City
# register wrong name (40.6711978, -73.97484126) Garfield Pl & 8 Ave
# register wrong name (40.6767, -73.969024) Park Pl & Vanderbilt Ave
# rename (40.682601, -73.938037) Marcus Garvey Blvd & Macon St
# register wrong name (40.6881529, -73.99520919) Congress St & Clinton St
# register wrong name (40.68825516598005, -73.99545192718506) 4455.10
# rename (40.688489, -73.99116) Boerum Pl\t& Pacific St
# error data (40.68848905639242, -73.99116039276123) 5653
# error data (40.692, -73.992) 4
# rename (40.69757, -73.93098) Willoughby Ave & Myrtle Ave
# rename (40.698477, -73.98384) Nassau St\t& Duffield St
# rename (40.70684203101325, -73.9544353965357) Division Av & Hooper St
# rename (40.70831794366396, -74.00504082441329) Cliff St & Fulton St
# register wrong name (40.71146364, -74.00552427) Spruce St & Nassau St
# rename (40.711471, -73.986726) Clinton St\t& Cherry St
# error data (40.711471394469264, -73.98672603070736) 9533
# rename (40.71413089, -73.9970468) Division St & Bowery
# register wrong name (40.71754834, -74.01322069) West St & Chambers St
# rename (40.717798, -73.993161) Forsyth St\t& Grand St
# error data (40.71779817737835, -73.99316132068634) 13604
# error data (40.719, -74.007) 4
# error data (40.719, -74.001) 2
# error data (40.720828, -73.977931) 10254
# error data (40.722992, -73.979954) 6245
# register wrong name (40.72362738, -73.99949601) Mercer St & Spring St
# register wrong name (40.72368361, -73.97574813) Avenue D & E 8 St
# rename (40.72430527250332, -73.99600982666016) Lafayette St & Jersey St
# rename (40.72494672359416, -74.00165855884552) W Broadway & Spring Street
# rename (40.726156, -73.995101) Bleecker St & Crosby St
# error data (40.7284, -73.999687) 12053
# rename (40.72917025, -73.99810231) LaGuardia Pl & W 3 St
# rename (40.73026, -73.95394) Greenpoint Ave & Manhattan Ave
# error data (40.731, -73.992) 2
# register wrong name (40.731539, -73.985302) E 13 St & 2 Ave
# rename (40.73221853, -73.98165557) 1 Ave & E 16 St
# rename (40.73381219196632, -73.98054420948029) 1 Ave & E 18 St
# error data (40.734, -73.992) 2
# error data (40.737, -73.989) 3
# error data (40.737, -73.977) 6
# rename (40.741459, -73.983293) Lexington Ave & E 26 St
# rename (40.74311555376486, -73.98215353488922) Lexington Ave & E 29 St
# error data (40.746, -73.998) 7
# rename (40.749156, -73.9916) W 31 St & 7 Ave
# register wrong name (40.75019995, -73.99093085) W 33 St & 7 Ave
# register wrong name (40.751581, -73.97791) Pershing Square South
# error data (40.752, -73.995) 5
# error data (40.752, -73.989) 3
# error data (40.752, -73.977) 4
# rename (40.7527085, -73.9397405) 24 St & 41 Ave
# register wrong name (40.755293, -73.967641) E 51 St & 2 Ave
# register wrong name (40.75668720603179, -73.98257732391357) W 45 St & 6 Ave -
# rename (40.757764, -73.907654) 51 St & Hobart St
# rename (40.75892386377695, -73.96226227283478) E 58 St & 1 Ave
# rename (40.759125, -73.962658) E 58 St &  1 Ave (NW Corner)
# rename (40.761293897289086, -73.916916847229) 31 Ave & Steinway St
# register wrong name (40.76669671, -73.99061728) W 53 St & 10 Ave
# error data (40.77, -73.989) 2
# error data (40.770374, -73.928607) 1838
# rename (40.771203, -73.903865) Ditmars Ave & 43 St
# rename (40.77282817, -73.96685276) 5 Ave & E 73 St
# error data (40.776, -73.983) 2
# register wrong name (40.78057799010334, -73.98562431335449) Riverside Dr & W 72 St
# rename (40.78472675, -73.96961715) Central Park West & W 85 St
# error data (40.788, -73.953) 2
# error data (40.803, -73.956) 5
# register wrong name (40.80698, -73.941747) 5 Ave & E 126 St
# rename (40.807258, -73.907999) Southern Blvd & E 142 St
# error data (40.808442, -73.945208) 10382
# rename (40.814232, -73.903927) Propsect Ave & E 151 St
# rename (40.816234, -73.948222) St Nicholas Ave & E 134 St
# register wrong name (40.81687039466032, -73.92798498272896) Grand Concourse & E 144  St
# register wrong name (40.829114, -73.950426) Riverside Dr & W 148 St
# rename (40.836103, -73.907199) E 170 St & Webster Ave
# rename (40.84224, -73.8985) 3 Ave & E 174 St
# register wrong name (40.86448, -73.89522) Grand Concourse & E 192 St

# %%
m_station_NYC = station_NYC.drop(index=drop_index)
m_station_NYC
# Out:
#                     start_station_name  start_lat  start_lng
# 0          Central Park West & W 76 St  40.778968 -73.973747
# 1                Pershing Square North  40.751873 -73.977706
# 2              Amsterdam Ave & W 82 St  40.785247 -73.976673
# 3                      1 Ave & E 16 St  40.732219 -73.981656
# 4                       Great Jones St  40.727434 -73.993790
# ...                                ...        ...        ...
# 36929       Grand Concourse & E 144 St  40.816870 -73.927985
# 36960             Vesey St & Church St  40.712220 -74.010472
# 37561                  E 39 St & 2 Ave  40.748033 -73.973828
# 37794                  E 91 St & 2 Ave  40.781152 -73.949630
# 37887  W 168th S & Fort Washington Ave  40.842102 -73.942240
#
# [3136 rows x 3 columns]

# %%
view_list = m_station_NYC.loc[m_station_NYC.duplicated(subset=['start_lat','start_lng'],keep=False)].sort_values(['start_lat','start_lng'])
view_list
# Out:
# Empty DataFrame
# Columns: [start_station_name, start_lat, start_lng]
# Index: []

# %%
m_station_NYC.to_csv('.\\m_station_NYC.csv')

# %%
need_modify_station = pd.DataFrame({'name' : name, 'lat' : lat, 'lng' : lng})
need_modify_station.to_csv('.\\need_modify_station.csv')

# %%
for i in range(len(name)):
    station_data.loc[(station_data['start_lat'] == lat[i]) & (station_data['start_lng'] == lng[i]), 'start_station_name'] = name[i]
    station_data.loc[(station_data['end_lat'] == lat[i]) & (station_data['end_lng'] == lng[i]), 'end_station_name'] = name[i]

for i in range(len(d_lat)):
    station_data.drop(index=station_data[(station_data['start_lat'] == d_lat[i]) & (station_data['start_lng'] == d_lng[i])].index[0])

# %%
id_map = {v:i for i, v in enumerate(m_station_NYC['start_station_name'])}
station_data['start_id'] = station_data['start_station_name'].apply(lambda x: id_map[x] if x in id_map else np.NaN)
station_data['end_id'] = station_data['end_station_name'].apply(lambda x: id_map[x] if x in id_map else np.NaN)

station_data.to_csv('.\\m_station_data.csv')

# %%
import os
import pandas as pd 
import numpy as np
import datetime as d
import calendar as c 
from datetime import timedelta

station_data = pd.read_csv('.\\m_station_data.csv', usecols=['started_at','ended_at','start_station_name','start_lat','start_lng','end_station_name','end_lat','end_lng','start_id','end_id'])
station_data.head()
# Out:
#                  started_at                  ended_at  \
# 0  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#             start_station_name  start_lat  start_lng        end_station_name  \
# 0  Central Park West & W 76 St  40.778968 -73.973747  W 89 St & Columbus Ave
# 1        Pershing Square North  40.751873 -73.977706         E 39 St & 2 Ave
# 2      Amsterdam Ave & W 82 St  40.785247 -73.976673         E 77 St & 3 Ave
# 3              1 Ave & E 16 St  40.732219 -73.981656         W 15 St & 6 Ave
# 4               Great Jones St  40.727434 -73.993790      E 20 St & Park Ave
#
#      end_lat    end_lng  start_id  end_id
# 0  40.788221 -73.970416    2494.0  1669.0
# 1  40.747804 -73.973442       1.0  3133.0
# 2  40.773142 -73.958562    2263.0  2285.0
# 3  40.738046 -73.996430    1803.0  1932.0
# 4  40.738274 -73.987520    1634.0  1940.0

# %%
station_data['started_at'] = pd.to_datetime(station_data['started_at'], format='%Y-%m-%d %H:%M:%S')
station_data['ended_at'] = pd.to_datetime(station_data['ended_at'], format='%Y-%m-%d %H:%M:%S')
station_data.head()
# Out:
#                started_at                ended_at  \
# 0 2019-01-01 00:01:47.401 2019-01-01 00:07:07.581
# 1 2019-01-01 00:04:43.736 2019-01-01 00:10:00.608
# 2 2019-01-01 00:06:03.997 2019-01-01 00:15:55.438
# 3 2019-01-01 00:07:03.545 2019-01-01 00:52:22.650
# 4 2019-01-01 00:07:35.945 2019-01-01 00:12:39.502
#
#             start_station_name  start_lat  start_lng        end_station_name  \
# 0  Central Park West & W 76 St  40.778968 -73.973747  W 89 St & Columbus Ave
# 1        Pershing Square North  40.751873 -73.977706         E 39 St & 2 Ave
# 2      Amsterdam Ave & W 82 St  40.785247 -73.976673         E 77 St & 3 Ave
# 3              1 Ave & E 16 St  40.732219 -73.981656         W 15 St & 6 Ave
# 4               Great Jones St  40.727434 -73.993790      E 20 St & Park Ave
#
#      end_lat    end_lng  start_id  end_id
# 0  40.788221 -73.970416    2494.0  1669.0
# 1  40.747804 -73.973442       1.0  3133.0
# 2  40.773142 -73.958562    2263.0  2285.0
# 3  40.738046 -73.996430    1803.0  1932.0
# 4  40.738274 -73.987520    1634.0  1940.0

# %%
delta_incres = 60
current_time = d.datetime(2019, 1, 1)
end_time = d.datetime(2021, 9, 1)
m_station_NYC = pd.read_csv('.\\m_station_NYC.csv', usecols=['start_station_name','start_lat','start_lng'])

result_station = []
while current_time <= end_time:
    day_num = c.monthrange(current_time.year, current_time.month)[1]
    result_station.append(np.zeros([(1440 // delta_incres * day_num), m_station_NYC.shape[0], 2], dtype=int))
    current_time += timedelta(days=day_num)

# %%
for i in range(station_data.shape[0]):
    start_id = station_data.loc[i, 'start_id']
    end_id = station_data.loc[i, 'end_id']

    if (not np.isnan(start_id)) and (not np.isnan(end_id)):
        started_at = station_data.loc[i, 'started_at']
        s_0 = (started_at.year-2019)*12 + (started_at.month-1)
        s_1 = ((started_at.day-1)*24*60 + (started_at.hour)*60 + (started_at.minute)) // delta_incres
        result_station[s_0][s_1][int(start_id)][0] += 1
    
        ended_at = station_data.loc[i, 'ended_at']
        e_0 = (ended_at.year-2019)*12 + (ended_at.month-1)
        e_1 = ((ended_at.day-1)*24*60 + (ended_at.hour)*60 + (ended_at.minute)) // delta_incres
        result_station[e_0][e_1][int(end_id)][1] += 1

# %%
current_time = d.datetime(2019, 1, 1)
end_time = d.datetime(2021, 9, 1)

i = 0
while current_time <= end_time:
    day_num = c.monthrange(current_time.year, current_time.month)[1]
    np.save(('.\\processed_data\\{}{:02d}_.npy'.format(current_time.year, current_time.month)), result_station[i])
    current_time += timedelta(days=day_num)
    i += 1
