# %%
import torch
from torch import nn
from NpyDataset import NpyDataset
from AutoEncoder import AutoEncoder
from torch.autograd import Variable
from torch.utils.data import DataLoader

# %%
num_epochs = 100
batch_size = 64
learning_rate = 1e-3

# %%
dataset = NpyDataset('../OD_data/201901_zone.npy')
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
model = AutoEncoder().cuda()

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)

# %%
for epoch in range(num_epochs):
    for data in dataloader:
        data = Variable(data).cuda()

        output = model(data)
        loss = criterion(output, data)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.data.item()))

torch.save(model.state_dict(), './autoencoder.pth')
# Out:
# epoch [1/100], loss:3.5458
# epoch [2/100], loss:3.6661
# epoch [3/100], loss:3.7471
# epoch [4/100], loss:3.0448
# epoch [5/100], loss:2.3167
# epoch [6/100], loss:3.2650
# epoch [7/100], loss:2.7933
# epoch [8/100], loss:3.0106
# epoch [9/100], loss:2.3339
# epoch [10/100], loss:2.5725
# epoch [11/100], loss:2.1878
# epoch [12/100], loss:1.4060
# epoch [13/100], loss:2.0774
# epoch [14/100], loss:1.4143
# epoch [15/100], loss:1.8333
# epoch [16/100], loss:2.1686
# epoch [17/100], loss:1.8498
# epoch [18/100], loss:2.4275
# epoch [19/100], loss:1.9428
# epoch [20/100], loss:1.5383
# epoch [21/100], loss:1.8555
# epoch [22/100], loss:2.2204
# epoch [23/100], loss:2.3388
# epoch [24/100], loss:2.6171
# epoch [25/100], loss:1.7850
# epoch [26/100], loss:1.6220
# epoch [27/100], loss:2.0560
# epoch [28/100], loss:1.9667
# epoch [29/100], loss:1.6048
# epoch [30/100], loss:1.8368
# epoch [31/100], loss:1.4168
# epoch [32/100], loss:2.5975
# epoch [33/100], loss:1.8992
# epoch [34/100], loss:1.7798
# epoch [35/100], loss:1.5274
# epoch [36/100], loss:1.8103
# epoch [37/100], loss:1.6356
# epoch [38/100], loss:1.5870
# epoch [39/100], loss:2.3659
# epoch [40/100], loss:1.2642
# epoch [41/100], loss:1.5745
# epoch [42/100], loss:1.6371
# epoch [43/100], loss:1.7212
# epoch [44/100], loss:1.2226
# epoch [45/100], loss:2.2768
# epoch [46/100], loss:1.8225
# epoch [47/100], loss:1.2102
# epoch [48/100], loss:1.5624
# epoch [49/100], loss:1.6862
# epoch [50/100], loss:1.4955
# epoch [51/100], loss:1.6438
# epoch [52/100], loss:2.3934
# epoch [53/100], loss:1.7458
# epoch [54/100], loss:1.4083
# epoch [55/100], loss:1.8602
# epoch [56/100], loss:1.9407
# epoch [57/100], loss:1.5545
# epoch [58/100], loss:1.6005
# epoch [59/100], loss:1.8985
# epoch [60/100], loss:1.5421
# epoch [61/100], loss:1.8786
# epoch [62/100], loss:2.1872
# epoch [63/100], loss:2.4414
# epoch [64/100], loss:1.7562
# epoch [65/100], loss:1.1029
# epoch [66/100], loss:1.4351
# epoch [67/100], loss:1.6600
# epoch [68/100], loss:1.7613
# epoch [69/100], loss:1.7336
# epoch [70/100], loss:1.4787
# epoch [71/100], loss:1.5600
# epoch [72/100], loss:1.4650
# epoch [73/100], loss:1.8262
# epoch [74/100], loss:2.0855
# epoch [75/100], loss:2.0068
# epoch [76/100], loss:1.7635
# epoch [77/100], loss:1.9680
# epoch [78/100], loss:1.7147
# epoch [79/100], loss:1.5955
# epoch [80/100], loss:1.5698
# epoch [81/100], loss:1.0308
# epoch [82/100], loss:1.5362
# epoch [83/100], loss:1.1818
# epoch [84/100], loss:1.9944
# epoch [85/100], loss:2.2887
# epoch [86/100], loss:2.2983
# epoch [87/100], loss:1.4567
# epoch [88/100], loss:1.6006
# epoch [89/100], loss:1.7576
# epoch [90/100], loss:1.6058
# epoch [91/100], loss:1.7144
# epoch [92/100], loss:1.8731
# epoch [93/100], loss:1.7779
# epoch [94/100], loss:1.6407
# epoch [95/100], loss:2.1512
# epoch [96/100], loss:2.2164
# epoch [97/100], loss:1.8862
# epoch [98/100], loss:2.1803
# epoch [99/100], loss:1.3979
# epoch [100/100], loss:1.8399
